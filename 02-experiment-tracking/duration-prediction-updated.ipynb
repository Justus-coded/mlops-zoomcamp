# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.linear_model import Lasso

# %%
from sklearn.linear_model import Ridge

# %%
from sklearn.metrics import mean_squared_error

# %%
#pip install xgboost
#pip install hyperopt

# %%
import xgboost as xgb

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
from mlflow.tracking import MlflowClient

MLFLOW_TRACKING_URI = "sqlite:///mlflow.db"

client = MlflowClient(tracking_uri=MLFLOW_TRACKING_URI)

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# <Experiment: artifact_location='/workspaces/mlops-zoomcamp/02-experiment-tracking/mlruns/1', creation_time=1717038746543, experiment_id='1', last_update_time=1717038746543, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
#### Modularizing the code 

def read_dataframe(filename):

    df = pd.read_parquet(filename)
    df['duration'] = df.lpep_dropoff_datetime  - df.lpep_pickup_datetime   
    df['duration'] = df['duration'].apply(lambda td: td.total_seconds()/60)

    df = df[((df.duration>=1) & (df.duration<=60))]

    categorical =['PULocationID','DOLocationID' ]
    #numerical =['trip_distance']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-01.parquet')
df_val = read_dataframe('https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical =  ['PU_DO'] #['PULocationID','DOLocationID' ]
numerical =['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical ].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target ='duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 7.480879703714338

# %%
with mlflow.start_run():
    
    mlflow.set_tag("developer", "Justus")
    
    mlflow.set_tag("model_name", "Lasso")
    
    mlflow.log_param("train-url", "green_tripdata_2021-01.parquet")
    mlflow.log_param("val-url", "green_tripdata_2021-02.parquet")
    
    alpha = 0.001
    mlflow.log_param("alpha", alpha)

    lr = Lasso(0.001)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)
    #
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    
    mlflow.log_metric("rmse", rmse)

# %%
with mlflow.start_run():
    
    mlflow.set_tag("developer", "Justus")
    
    mlflow.set_tag("model_name", "Ridge")
    
    mlflow.log_param("train-url", "green_tripdata_2021-01.parquet")
    mlflow.log_param("val-url", "green_tripdata_2021-02.parquet")
    
    alpha = 0.001
    mlflow.log_param("alpha", alpha)


    lr = Ridge(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)

    rmse =mean_squared_error(y_val, y_pred, squared=False)
    
    mlflow.log_metric("rmse", rmse)

# %%
import pickle

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv,lr), f_out)

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)

# %%
params = {
    'learning_rate' : 0.20472,
    'max_depth' : 17,
    'min_child_weight' : 1.24026117, 
    'objective': 'reg:linear',
    'reg_alpha': 0.28567,
    'reg_lambda': 0.0042644,
    'seed': 42
    
}

mlflow.xgboost.autolog()

booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
# Out:
# 2024/05/30 19:27:15 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'fd11023e506748aebf05cea5da7118c4', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# /home/codespace/anaconda3/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [19:27:20] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:11.98179
# [1]	validation-rmse:11.83350
# [2]	validation-rmse:11.73825
# [3]	validation-rmse:11.65759
# [4]	validation-rmse:11.59579
# [5]	validation-rmse:11.54758
# [6]	validation-rmse:11.50366
# [7]	validation-rmse:11.46061
# [8]	validation-rmse:11.41970
# [9]	validation-rmse:11.38580
# [10]	validation-rmse:11.35126
# [11]	validation-rmse:11.32099
# [12]	validation-rmse:11.28905
# [13]	validation-rmse:11.26045
# [14]	validation-rmse:11.23964
# [15]	validation-rmse:11.21157
# [16]	validation-rmse:11.19271
# [17]	validation-rmse:11.16952
# [18]	validation-rmse:11.14505
# [19]	validation-rmse:11.12726
# [20]	validation-rmse:11.10530
# [21]	validation-rmse:11.08596
# [22]	validation-rmse:11.06404
# [23]	validation-rmse:11.04630
# [24]	validation-rmse:11.02613
# [25]	validation-rmse:11.00776
# [26]	validation-rmse:10.98970
# [27]	validation-rmse:10.97370
# [28]	validation-rmse:10.95542
# [29]	validation-rmse:10.93649
# [30]	validation-rmse:10.92504
# [31]	validation-rmse:10.90775
# [32]	validation-rmse:10.89888
# [33]	validation-rmse:10.88266
# [34]	validation-rmse:10.87174
# [35]	validation-rmse:10.85721
# [36]	validation-rmse:10.84533
# [37]	validation-rmse:10.82996
# [38]	validation-rmse:10.81698
# [39]	validation-rmse:10.80794
# [40]	validation-rmse:10.79473
# [41]	validation-rmse:10.78169
# [42]	validation-rmse:10.76824
# [43]	validation-rmse:10.75594
# [44]	validation-rmse:10.74685
# [45]	validation-rmse:10.73142
# [46]	validation-rmse:10.71898
# [47]	validation-rmse:10.71003
# [48]	validation-rmse:10.70213
# [49]	validation-rmse:10.68991
# [50]	validation-rmse:10.67731
# [51]	validation-rmse:10.66798
# [52]	validation-rmse:10.65494
# [53]	validation-rmse:10.64259
# [54]	validation-rmse:10.63592
# [55]	validation-rmse:10.62939
# [56]	validation-rmse:10.61939
# [57]	validation-rmse:10.61305
# [58]	validation-rmse:10.60197
# [59]	validation-rmse:10.59089
# [60]	validation-rmse:10.58415
# [61]	validation-rmse:10.57370
# [62]	validation-rmse:10.56677
# [63]	validation-rmse:10.55637
# [64]	validation-rmse:10.55071
# [65]	validation-rmse:10.54030
# [66]	validation-rmse:10.53246
# [67]	validation-rmse:10.52172
# [68]	validation-rmse:10.51658
# [69]	validation-rmse:10.50589
# [70]	validation-rmse:10.49781
# [71]	validation-rmse:10.48841
# [72]	validation-rmse:10.48338
# [73]	validation-rmse:10.47663
# [74]	validation-rmse:10.46967
# [75]	validation-rmse:10.45830
# [76]	validation-rmse:10.45261
# [77]	validation-rmse:10.44787
# [78]	validation-rmse:10.43811
# [79]	validation-rmse:10.42858
# [80]	validation-rmse:10.42252
# [81]	validation-rmse:10.41451
# [82]	validation-rmse:10.40979
# [83]	validation-rmse:10.39985
# [84]	validation-rmse:10.39341
# [85]	validation-rmse:10.38636
# [86]	validation-rmse:10.38330
# [87]	validation-rmse:10.37413
# [88]	validation-rmse:10.36775
# [89]	validation-rmse:10.36247
# [90]	validation-rmse:10.35606
# [91]	validation-rmse:10.34642
# [92]	validation-rmse:10.33845
# [93]	validation-rmse:10.33297
# [94]	validation-rmse:10.32491
# [95]	validation-rmse:10.32077
# [96]	validation-rmse:10.31504
# [97]	validation-rmse:10.30674
# [98]	validation-rmse:10.29846
# [99]	validation-rmse:10.29207
# [100]	validation-rmse:10.28736
# [101]	validation-rmse:10.27884
# [102]	validation-rmse:10.27194
# [103]	validation-rmse:10.26681
# [104]	validation-rmse:10.25868
# [105]	validation-rmse:10.25439
# [106]	validation-rmse:10.24925
# [107]	validation-rmse:10.24312
# [108]	validation-rmse:10.23896
# [109]	validation-rmse:10.23237
# [110]	validation-rmse:10.22556
# [111]	validation-rmse:10.22060
# [112]	validation-rmse:10.21636
# [113]	validation-rmse:10.20826
# [114]	validation-rmse:10.20090
# [115]	validation-rmse:10.19468
# [116]	validation-rmse:10.19064
# [117]	validation-rmse:10.18645
# [118]	validation-rmse:10.17944
# [119]	validation-rmse:10.17719
# [120]	validation-rmse:10.17051
# [121]	validation-rmse:10.16644
# [122]	validation-rmse:10.16157
# [123]	validation-rmse:10.15567
# [124]	validation-rmse:10.15115
# [125]	validation-rmse:10.14792
# [126]	validation-rmse:10.14212
# [127]	validation-rmse:10.13482
# [128]	validation-rmse:10.13171
# [129]	validation-rmse:10.12578
# [130]	validation-rmse:10.12320
# [131]	validation-rmse:10.12250
# [132]	validation-rmse:10.11573
# [133]	validation-rmse:10.11123
# [134]	validation-rmse:10.10731
# [135]	validation-rmse:10.10067
# [136]	validation-rmse:10.09605
# [137]	validation-rmse:10.09341
# [138]	validation-rmse:10.08712
# [139]	validation-rmse:10.08338
# [140]	validation-rmse:10.07693
# [141]	validation-rmse:10.07113
# [142]	validation-rmse:10.06606
# [143]	validation-rmse:10.06062
# [144]	validation-rmse:10.05446
# [145]	validation-rmse:10.04862
# [146]	validation-rmse:10.04530
# [147]	validation-rmse:10.04132
# [148]	validation-rmse:10.03552
# [149]	validation-rmse:10.03150
# [150]	validation-rmse:10.02741
# [151]	validation-rmse:10.02149
# [152]	validation-rmse:10.01663
# [153]	validation-rmse:10.01191
# [154]	validation-rmse:10.00629
# [155]	validation-rmse:10.00288
# [156]	validation-rmse:9.99644
# [157]	validation-rmse:9.99387
# [158]	validation-rmse:9.98839
# [159]	validation-rmse:9.98583
# [160]	validation-rmse:9.98122
# [161]	validation-rmse:9.97560
# [162]	validation-rmse:9.97022
# [163]	validation-rmse:9.96729
# [164]	validation-rmse:9.96551
# [165]	validation-rmse:9.96286
# [166]	validation-rmse:9.95660
# [167]	validation-rmse:9.95131
# [168]	validation-rmse:9.94763
# [169]	validation-rmse:9.94398
# [170]	validation-rmse:9.93897
# [171]	validation-rmse:9.93401
# [172]	validation-rmse:9.93173
# [173]	validation-rmse:9.92665
# [174]	validation-rmse:9.92188
# [175]	validation-rmse:9.92036
# [176]	validation-rmse:9.91509
# [177]	validation-rmse:9.91015
# [178]	validation-rmse:9.90713
# [179]	validation-rmse:9.90446
# [180]	validation-rmse:9.89955
# [181]	validation-rmse:9.89479
# [182]	validation-rmse:9.89230
# [183]	validation-rmse:9.88920
# [184]	validation-rmse:9.88382
# [185]	validation-rmse:9.88040
# [186]	validation-rmse:9.87585
# [187]	validation-rmse:9.87397
# [188]	validation-rmse:9.86977
# [189]	validation-rmse:9.86587
# [190]	validation-rmse:9.86107
# [191]	validation-rmse:9.85661
# [192]	validation-rmse:9.85339
# [193]	validation-rmse:9.85038
# [194]	validation-rmse:9.84572
# [195]	validation-rmse:9.84209
# [196]	validation-rmse:9.83873
# [197]	validation-rmse:9.83395
# [198]	validation-rmse:9.83210
# [199]	validation-rmse:9.82766
# [200]	validation-rmse:9.82330
# [201]	validation-rmse:9.81899
# [202]	validation-rmse:9.81749
# [203]	validation-rmse:9.81267
# [204]	validation-rmse:9.80984
# [205]	validation-rmse:9.80452
# [206]	validation-rmse:9.79987
# [207]	validation-rmse:9.79732
# [208]	validation-rmse:9.79269
# [209]	validation-rmse:9.78955
# [210]	validation-rmse:9.78637
# [211]	validation-rmse:9.78170
# [212]	validation-rmse:9.78044
# [213]	validation-rmse:9.77742
# [214]	validation-rmse:9.77413
# [215]	validation-rmse:9.77001
# [216]	validation-rmse:9.76598
# [217]	validation-rmse:9.76177
# [218]	validation-rmse:9.75737
# [219]	validation-rmse:9.75618
# [220]	validation-rmse:9.75224
# [221]	validation-rmse:9.74986
# [222]	validation-rmse:9.74794
# [223]	validation-rmse:9.74598
# [224]	validation-rmse:9.74284
# [225]	validation-rmse:9.73863
# [226]	validation-rmse:9.73392
# [227]	validation-rmse:9.72999
# [228]	validation-rmse:9.72808
# [229]	validation-rmse:9.72385
# [230]	validation-rmse:9.71895
# [231]	validation-rmse:9.71663
# [232]	validation-rmse:9.71204
# [233]	validation-rmse:9.70906
# [234]	validation-rmse:9.70506
# [235]	validation-rmse:9.70052
# [236]	validation-rmse:9.69713
# [237]	validation-rmse:9.69594
# [238]	validation-rmse:9.69483
# [239]	validation-rmse:9.69038
# [240]	validation-rmse:9.68660
# [241]	validation-rmse:9.68549
# [242]	validation-rmse:9.68061
# [243]	validation-rmse:9.67814
# [244]	validation-rmse:9.67538
# [245]	validation-rmse:9.67359
# [246]	validation-rmse:9.66925
# [247]	validation-rmse:9.66465
# [248]	validation-rmse:9.66324
# [249]	validation-rmse:9.65957
# [250]	validation-rmse:9.65899
# [251]	validation-rmse:9.65584
# [252]	validation-rmse:9.65300
# [253]	validation-rmse:9.65006
# [254]	validation-rmse:9.64702
# [255]	validation-rmse:9.64307
# [256]	validation-rmse:9.64134
# [257]	validation-rmse:9.63885
# [258]	validation-rmse:9.63620
# [259]	validation-rmse:9.63155
# [260]	validation-rmse:9.62791
# [261]	validation-rmse:9.62460
# [262]	validation-rmse:9.62198
# [263]	validation-rmse:9.61997
# [264]	validation-rmse:9.61620
# [265]	validation-rmse:9.61288
# [266]	validation-rmse:9.60970
# [267]	validation-rmse:9.60853
# [268]	validation-rmse:9.60627
# [269]	validation-rmse:9.60283
# [270]	validation-rmse:9.60059
# [271]	validation-rmse:9.59657
# [272]	validation-rmse:9.59309
# [273]	validation-rmse:9.59043
# [274]	validation-rmse:9.58854
# [275]	validation-rmse:9.58489
# [276]	validation-rmse:9.58243
# [277]	validation-rmse:9.57996
# [278]	validation-rmse:9.57557
# [279]	validation-rmse:9.57268
# [280]	validation-rmse:9.57095
# [281]	validation-rmse:9.56718
# [282]	validation-rmse:9.56401
# [283]	validation-rmse:9.56198
# [284]	validation-rmse:9.55843
# [285]	validation-rmse:9.55499
# [286]	validation-rmse:9.55403
# [287]	validation-rmse:9.55007
# [288]	validation-rmse:9.54594
# [289]	validation-rmse:9.54438
# [290]	validation-rmse:9.54078
# [291]	validation-rmse:9.53760
# [292]	validation-rmse:9.53366
# [293]	validation-rmse:9.53260
# [294]	validation-rmse:9.53077
# [295]	validation-rmse:9.52884
# [296]	validation-rmse:9.52584
# [297]	validation-rmse:9.52364
# [298]	validation-rmse:9.52036
# [299]	validation-rmse:9.51833
# [300]	validation-rmse:9.51638
# [301]	validation-rmse:9.51479
# [302]	validation-rmse:9.51165
# [303]	validation-rmse:9.50897
# [304]	validation-rmse:9.50559
# [305]	validation-rmse:9.50376
# [306]	validation-rmse:9.50133
# [307]	validation-rmse:9.49855
# [308]	validation-rmse:9.49629
# [309]	validation-rmse:9.49247
# [310]	validation-rmse:9.48867
# [311]	validation-rmse:9.48528
# [312]	validation-rmse:9.48280
# [313]	validation-rmse:9.48137
# [314]	validation-rmse:9.47986
# [315]	validation-rmse:9.47583
# [316]	validation-rmse:9.47511
# [317]	validation-rmse:9.47194
# [318]	validation-rmse:9.47018
# [319]	validation-rmse:9.46782
# [320]	validation-rmse:9.46501
# [321]	validation-rmse:9.46147
# [322]	validation-rmse:9.45910
# [323]	validation-rmse:9.45553
# [324]	validation-rmse:9.45339
# [325]	validation-rmse:9.45061
# [326]	validation-rmse:9.44879
# [327]	validation-rmse:9.44626
# [328]	validation-rmse:9.44294
# [329]	validation-rmse:9.44119
# [330]	validation-rmse:9.43786
# [331]	validation-rmse:9.43593
# [332]	validation-rmse:9.43346
# [333]	validation-rmse:9.43040
# [334]	validation-rmse:9.42833
# [335]	validation-rmse:9.42692
# [336]	validation-rmse:9.42340
# [337]	validation-rmse:9.42125
# [338]	validation-rmse:9.41981
# [339]	validation-rmse:9.41618
# [340]	validation-rmse:9.41327
# [341]	validation-rmse:9.41064
# [342]	validation-rmse:9.40917
# [343]	validation-rmse:9.40746
# [344]	validation-rmse:9.40427
# [345]	validation-rmse:9.40047
# [346]	validation-rmse:9.39775
# [347]	validation-rmse:9.39556
# [348]	validation-rmse:9.39480
# [349]	validation-rmse:9.39085
# [350]	validation-rmse:9.38764
# [351]	validation-rmse:9.38519
# [352]	validation-rmse:9.38310
# [353]	validation-rmse:9.38027
# [354]	validation-rmse:9.37680
# [355]	validation-rmse:9.37532
# [356]	validation-rmse:9.37315
# [357]	validation-rmse:9.37198
# [358]	validation-rmse:9.37102
# [359]	validation-rmse:9.36803
# [360]	validation-rmse:9.36466
# [361]	validation-rmse:9.36361
# [362]	validation-rmse:9.36082
# [363]	validation-rmse:9.35884
# [364]	validation-rmse:9.35635
# [365]	validation-rmse:9.35476
# [366]	validation-rmse:9.35329
# [367]	validation-rmse:9.35146
# [368]	validation-rmse:9.34867
# [369]	validation-rmse:9.34642
# [370]	validation-rmse:9.34479
# [371]	validation-rmse:9.34139
# [372]	validation-rmse:9.33915
# [373]	validation-rmse:9.33806
# [374]	validation-rmse:9.33514
# [375]	validation-rmse:9.33296
# [376]	validation-rmse:9.33171
# [377]	validation-rmse:9.33026
# [378]	validation-rmse:9.32930
# [379]	validation-rmse:9.32701
# [380]	validation-rmse:9.32476
# [381]	validation-rmse:9.32372
# [382]	validation-rmse:9.32042
# [383]	validation-rmse:9.31945
# [384]	validation-rmse:9.31826
# [385]	validation-rmse:9.31563
# [386]	validation-rmse:9.31322
# [387]	validation-rmse:9.31121
# [388]	validation-rmse:9.30858
# [389]	validation-rmse:9.30578
# [390]	validation-rmse:9.30427
# [391]	validation-rmse:9.30174
# [392]	validation-rmse:9.29934
# [393]	validation-rmse:9.29702
# [394]	validation-rmse:9.29610
# [395]	validation-rmse:9.29364
# [396]	validation-rmse:9.29144
# [397]	validation-rmse:9.29017
# [398]	validation-rmse:9.28886
# [399]	validation-rmse:9.28596
# [400]	validation-rmse:9.28548
# [401]	validation-rmse:9.28310
# [402]	validation-rmse:9.28042
# [403]	validation-rmse:9.27895
# [404]	validation-rmse:9.27642
# [405]	validation-rmse:9.27516
# [406]	validation-rmse:9.27313
# [407]	validation-rmse:9.27171
# [408]	validation-rmse:9.26856
# [409]	validation-rmse:9.26811
# [410]	validation-rmse:9.26577
# [411]	validation-rmse:9.26456
# [412]	validation-rmse:9.26303
# [413]	validation-rmse:9.26159
# [414]	validation-rmse:9.26015
# [415]	validation-rmse:9.25781
# [416]	validation-rmse:9.25592
# [417]	validation-rmse:9.25455
# [418]	validation-rmse:9.25219
# [419]	validation-rmse:9.25088
# [420]	validation-rmse:9.25023
# [421]	validation-rmse:9.24730
# [422]	validation-rmse:9.24504
# [423]	validation-rmse:9.24252
# [424]	validation-rmse:9.24166
# [425]	validation-rmse:9.23892
# [426]	validation-rmse:9.23688
# [427]	validation-rmse:9.23541
# [428]	validation-rmse:9.23375
# [429]	validation-rmse:9.23128
# [430]	validation-rmse:9.23121
# [431]	validation-rmse:9.23044
# [432]	validation-rmse:9.22906
# [433]	validation-rmse:9.22672
# [434]	validation-rmse:9.22489
# [435]	validation-rmse:9.22239
# [436]	validation-rmse:9.22120
# [437]	validation-rmse:9.21844
# [438]	validation-rmse:9.21563
# [439]	validation-rmse:9.21478
# [440]	validation-rmse:9.21241
# [441]	validation-rmse:9.21066
# [442]	validation-rmse:9.20797
# [443]	validation-rmse:9.20577
# [444]	validation-rmse:9.20370
# [445]	validation-rmse:9.20211
# [446]	validation-rmse:9.19927
# [447]	validation-rmse:9.19721
# [448]	validation-rmse:9.19428
# [449]	validation-rmse:9.19362
# [450]	validation-rmse:9.19128
# [451]	validation-rmse:9.18918
# [452]	validation-rmse:9.18690
# [453]	validation-rmse:9.18575
# [454]	validation-rmse:9.18371
# [455]	validation-rmse:9.18266
# [456]	validation-rmse:9.18019
# [457]	validation-rmse:9.17823
# [458]	validation-rmse:9.17598
# [459]	validation-rmse:9.17411
# [460]	validation-rmse:9.17156
# [461]	validation-rmse:9.16936
# [462]	validation-rmse:9.16730
# [463]	validation-rmse:9.16494
# [464]	validation-rmse:9.16220
# [465]	validation-rmse:9.16123
# [466]	validation-rmse:9.15991
# [467]	validation-rmse:9.15830
# [468]	validation-rmse:9.15583
# [469]	validation-rmse:9.15478
# [470]	validation-rmse:9.15348
# [471]	validation-rmse:9.15092
# [472]	validation-rmse:9.14820
# [473]	validation-rmse:9.14605
# [474]	validation-rmse:9.14470
# [475]	validation-rmse:9.14331
# [476]	validation-rmse:9.14181
# [477]	validation-rmse:9.14060
# [478]	validation-rmse:9.13779
# [479]	validation-rmse:9.13628
# [480]	validation-rmse:9.13387
# [481]	validation-rmse:9.13224
# [482]	validation-rmse:9.13052
# [483]	validation-rmse:9.12962
# [484]	validation-rmse:9.12820
# [485]	validation-rmse:9.12598
# [486]	validation-rmse:9.12439
# [487]	validation-rmse:9.12303
# [488]	validation-rmse:9.12144
# [489]	validation-rmse:9.12013
# [490]	validation-rmse:9.11816
# [491]	validation-rmse:9.11684
# [492]	validation-rmse:9.11485
# [493]	validation-rmse:9.11213
# [494]	validation-rmse:9.11139
# [495]	validation-rmse:9.11059
# [496]	validation-rmse:9.10892
# [497]	validation-rmse:9.10664
# [498]	validation-rmse:9.10553
# [499]	validation-rmse:9.10347
# [500]	validation-rmse:9.10170
# [501]	validation-rmse:9.10063
# [502]	validation-rmse:9.09878
# [503]	validation-rmse:9.09665
# [504]	validation-rmse:9.09511
# [505]	validation-rmse:9.09266
# [506]	validation-rmse:9.09046
# [507]	validation-rmse:9.08901
# [508]	validation-rmse:9.08760
# [509]	validation-rmse:9.08665
# [510]	validation-rmse:9.08595
# [511]	validation-rmse:9.08397
# [512]	validation-rmse:9.08184
# [513]	validation-rmse:9.07994
# [514]	validation-rmse:9.07936
# [515]	validation-rmse:9.07745
# [516]	validation-rmse:9.07519
# [517]	validation-rmse:9.07411
# [518]	validation-rmse:9.07269
# [519]	validation-rmse:9.07195
# [520]	validation-rmse:9.06984
# [521]	validation-rmse:9.06857
# [522]	validation-rmse:9.06635
# [523]	validation-rmse:9.06484
# [524]	validation-rmse:9.06351
# [525]	validation-rmse:9.06200
# [526]	validation-rmse:9.06049
# [527]	validation-rmse:9.05856
# [528]	validation-rmse:9.05696
# [529]	validation-rmse:9.05527
# [530]	validation-rmse:9.05423
# [531]	validation-rmse:9.05253
# [532]	validation-rmse:9.05087
# [533]	validation-rmse:9.04897
# [534]	validation-rmse:9.04692
# [535]	validation-rmse:9.04519
# [536]	validation-rmse:9.04390
# [537]	validation-rmse:9.04212
# [538]	validation-rmse:9.04120
# [539]	validation-rmse:9.03968
# [540]	validation-rmse:9.03755
# [541]	validation-rmse:9.03575
# [542]	validation-rmse:9.03511
# [543]	validation-rmse:9.03264
# [544]	validation-rmse:9.03054
# [545]	validation-rmse:9.02920
# [546]	validation-rmse:9.02737
# [547]	validation-rmse:9.02564
# [548]	validation-rmse:9.02498
# [549]	validation-rmse:9.02268
# [550]	validation-rmse:9.02101
# [551]	validation-rmse:9.01913
# [552]	validation-rmse:9.01716
# [553]	validation-rmse:9.01626
# [554]	validation-rmse:9.01397
# [555]	validation-rmse:9.01198
# [556]	validation-rmse:9.01026
# [557]	validation-rmse:9.00957
# [558]	validation-rmse:9.00779
# [559]	validation-rmse:9.00614
# [560]	validation-rmse:9.00524
# [561]	validation-rmse:9.00332
# [562]	validation-rmse:9.00207
# [563]	validation-rmse:9.00045
# [564]	validation-rmse:8.99892
# [565]	validation-rmse:8.99723
# [566]	validation-rmse:8.99530
# [567]	validation-rmse:8.99398
# [568]	validation-rmse:8.99322
# [569]	validation-rmse:8.99106
# [570]	validation-rmse:8.98980
# [571]	validation-rmse:8.98871
# [572]	validation-rmse:8.98788
# [573]	validation-rmse:8.98639
# [574]	validation-rmse:8.98440
# [575]	validation-rmse:8.98279
# [576]	validation-rmse:8.98128
# [577]	validation-rmse:8.98038
# [578]	validation-rmse:8.97984
# [579]	validation-rmse:8.97824
# [580]	validation-rmse:8.97756
# [581]	validation-rmse:8.97579
# [582]	validation-rmse:8.97398
# [583]	validation-rmse:8.97317
# [584]	validation-rmse:8.97142
# [585]	validation-rmse:8.96978
# [586]	validation-rmse:8.96791
# [587]	validation-rmse:8.96658
# [588]	validation-rmse:8.96463
# [589]	validation-rmse:8.96329
# [590]	validation-rmse:8.96185
# [591]	validation-rmse:8.96009
# [592]	validation-rmse:8.95951
# [593]	validation-rmse:8.95834
# [594]	validation-rmse:8.95787
# [595]	validation-rmse:8.95677
# [596]	validation-rmse:8.95496
# [597]	validation-rmse:8.95315
# [598]	validation-rmse:8.95139
# [599]	validation-rmse:8.95025
# [600]	validation-rmse:8.94793
# [601]	validation-rmse:8.94556
# [602]	validation-rmse:8.94349
# [603]	validation-rmse:8.94177
# [604]	validation-rmse:8.94006
# [605]	validation-rmse:8.93888
# [606]	validation-rmse:8.93691
# [607]	validation-rmse:8.93551
# [608]	validation-rmse:8.93426
# [609]	validation-rmse:8.93306
# [610]	validation-rmse:8.93242
# [611]	validation-rmse:8.93118
# [612]	validation-rmse:8.92928
# [613]	validation-rmse:8.92841
# [614]	validation-rmse:8.92758
# [615]	validation-rmse:8.92609
# [616]	validation-rmse:8.92532
# [617]	validation-rmse:8.92432
# [618]	validation-rmse:8.92280
# [619]	validation-rmse:8.92125
# [620]	validation-rmse:8.92031
# [621]	validation-rmse:8.91983
# [622]	validation-rmse:8.91877
# [623]	validation-rmse:8.91814
# [624]	validation-rmse:8.91664
# [625]	validation-rmse:8.91518
# [626]	validation-rmse:8.91443
# [627]	validation-rmse:8.91284
# [628]	validation-rmse:8.91152
# [629]	validation-rmse:8.91058
# [630]	validation-rmse:8.90880
# [631]	validation-rmse:8.90823
# [632]	validation-rmse:8.90821
# [633]	validation-rmse:8.90743
# [634]	validation-rmse:8.90591
# [635]	validation-rmse:8.90442
# [636]	validation-rmse:8.90456
# [637]	validation-rmse:8.90333
# [638]	validation-rmse:8.90211
# [639]	validation-rmse:8.90134
# [640]	validation-rmse:8.90028
# [641]	validation-rmse:8.89856
# [642]	validation-rmse:8.89781
# [643]	validation-rmse:8.89634
# [644]	validation-rmse:8.89497
# [645]	validation-rmse:8.89408
# [646]	validation-rmse:8.89326
# [647]	validation-rmse:8.89174
# [648]	validation-rmse:8.88973
# [649]	validation-rmse:8.88780
# [650]	validation-rmse:8.88641
# [651]	validation-rmse:8.88528
# [652]	validation-rmse:8.88372
# [653]	validation-rmse:8.88240
# [654]	validation-rmse:8.88145
# [655]	validation-rmse:8.88006
# [656]	validation-rmse:8.87838
# [657]	validation-rmse:8.87716
# [658]	validation-rmse:8.87613
# [659]	validation-rmse:8.87578
# [660]	validation-rmse:8.87425
# [661]	validation-rmse:8.87234
# [662]	validation-rmse:8.87117
# [663]	validation-rmse:8.86969
# [664]	validation-rmse:8.86788
# [665]	validation-rmse:8.86614
# [666]	validation-rmse:8.86449
# [667]	validation-rmse:8.86275
# [668]	validation-rmse:8.86166
# [669]	validation-rmse:8.86085
# [670]	validation-rmse:8.85951
# [671]	validation-rmse:8.85878
# [672]	validation-rmse:8.85767
# [673]	validation-rmse:8.85663
# [674]	validation-rmse:8.85473
# [675]	validation-rmse:8.85360
# [676]	validation-rmse:8.85202
# [677]	validation-rmse:8.85058
# [678]	validation-rmse:8.84941
# [679]	validation-rmse:8.84825
# [680]	validation-rmse:8.84752
# [681]	validation-rmse:8.84582
# [682]	validation-rmse:8.84437
# [683]	validation-rmse:8.84424
# [684]	validation-rmse:8.84279
# [685]	validation-rmse:8.84247
# [686]	validation-rmse:8.84207
# [687]	validation-rmse:8.84087
# [688]	validation-rmse:8.83898
# [689]	validation-rmse:8.83826
# [690]	validation-rmse:8.83677
# [691]	validation-rmse:8.83584
# [692]	validation-rmse:8.83427
# [693]	validation-rmse:8.83406
# [694]	validation-rmse:8.83280
# [695]	validation-rmse:8.83110
# [696]	validation-rmse:8.82974
# [697]	validation-rmse:8.82819
# [698]	validation-rmse:8.82671
# [699]	validation-rmse:8.82617
# [700]	validation-rmse:8.82485
# [701]	validation-rmse:8.82472
# [702]	validation-rmse:8.82352
# [703]	validation-rmse:8.82158
# [704]	validation-rmse:8.82042
# [705]	validation-rmse:8.81954
# [706]	validation-rmse:8.81797
# [707]	validation-rmse:8.81688
# [708]	validation-rmse:8.81552
# [709]	validation-rmse:8.81415
# [710]	validation-rmse:8.81253
# [711]	validation-rmse:8.81098
# [712]	validation-rmse:8.80955
# [713]	validation-rmse:8.80842
# [714]	validation-rmse:8.80738
# [715]	validation-rmse:8.80727
# [716]	validation-rmse:8.80617
# [717]	validation-rmse:8.80519
# [718]	validation-rmse:8.80458
# [719]	validation-rmse:8.80281
# [720]	validation-rmse:8.80131
# [721]	validation-rmse:8.79981
# [722]	validation-rmse:8.79899
# [723]	validation-rmse:8.79827
# [724]	validation-rmse:8.79753
# [725]	validation-rmse:8.79618
# [726]	validation-rmse:8.79530
# [727]	validation-rmse:8.79431
# [728]	validation-rmse:8.79310
# [729]	validation-rmse:8.79208
# [730]	validation-rmse:8.79085
# [731]	validation-rmse:8.78941
# [732]	validation-rmse:8.78838
# [733]	validation-rmse:8.78747
# [734]	validation-rmse:8.78714
# [735]	validation-rmse:8.78571
# [736]	validation-rmse:8.78449
# [737]	validation-rmse:8.78330
# [738]	validation-rmse:8.78236
# [739]	validation-rmse:8.78106
# [740]	validation-rmse:8.78066
# [741]	validation-rmse:8.77921
# [742]	validation-rmse:8.77826
# [743]	validation-rmse:8.77720
# [744]	validation-rmse:8.77589
# [745]	validation-rmse:8.77462
# [746]	validation-rmse:8.77347
# [747]	validation-rmse:8.77235
# [748]	validation-rmse:8.77097
# [749]	validation-rmse:8.76954
# [750]	validation-rmse:8.76843
# [751]	validation-rmse:8.76790
# [752]	validation-rmse:8.76668
# [753]	validation-rmse:8.76560
# [754]	validation-rmse:8.76445
# [755]	validation-rmse:8.76331
# [756]	validation-rmse:8.76201
# [757]	validation-rmse:8.76037
# [758]	validation-rmse:8.75887
# [759]	validation-rmse:8.75765
# [760]	validation-rmse:8.75690
# [761]	validation-rmse:8.75627
# [762]	validation-rmse:8.75485
# [763]	validation-rmse:8.75382
# [764]	validation-rmse:8.75308
# [765]	validation-rmse:8.75164
# [766]	validation-rmse:8.75053
# [767]	validation-rmse:8.74931
# [768]	validation-rmse:8.74843
# [769]	validation-rmse:8.74763
# [770]	validation-rmse:8.74679
# [771]	validation-rmse:8.74622
# [772]	validation-rmse:8.74520
# [773]	validation-rmse:8.74443
# [774]	validation-rmse:8.74346
# [775]	validation-rmse:8.74187
# [776]	validation-rmse:8.74045
# [777]	validation-rmse:8.73936
# [778]	validation-rmse:8.73817
# [779]	validation-rmse:8.73684
# [780]	validation-rmse:8.73524
# [781]	validation-rmse:8.73391
# [782]	validation-rmse:8.73285
# [783]	validation-rmse:8.73144
# [784]	validation-rmse:8.73004
# [785]	validation-rmse:8.72947
# [786]	validation-rmse:8.72898
# [787]	validation-rmse:8.72769
# [788]	validation-rmse:8.72696
# [789]	validation-rmse:8.72577
# [790]	validation-rmse:8.72540
# [791]	validation-rmse:8.72490
# [792]	validation-rmse:8.72371
# [793]	validation-rmse:8.72258
# [794]	validation-rmse:8.72186
# [795]	validation-rmse:8.72119
# [796]	validation-rmse:8.72038
# [797]	validation-rmse:8.71956
# [798]	validation-rmse:8.71793
# [799]	validation-rmse:8.71675
# [800]	validation-rmse:8.71552
# [801]	validation-rmse:8.71513
# [802]	validation-rmse:8.71452
# [803]	validation-rmse:8.71319
# [804]	validation-rmse:8.71204
# [805]	validation-rmse:8.71137
# [806]	validation-rmse:8.70996
# [807]	validation-rmse:8.70864
# [808]	validation-rmse:8.70776
# [809]	validation-rmse:8.70677
# [810]	validation-rmse:8.70643
# [811]	validation-rmse:8.70573
# [812]	validation-rmse:8.70515
# [813]	validation-rmse:8.70427
# [814]	validation-rmse:8.70378
# [815]	validation-rmse:8.70278
# [816]	validation-rmse:8.70115
# [817]	validation-rmse:8.70031
# [818]	validation-rmse:8.69969
# [819]	validation-rmse:8.69864
# [820]	validation-rmse:8.69735
# [821]	validation-rmse:8.69663
# [822]	validation-rmse:8.69484
# [823]	validation-rmse:8.69345
# [824]	validation-rmse:8.69248
# [825]	validation-rmse:8.69144
# [826]	validation-rmse:8.69060
# [827]	validation-rmse:8.68930
# [828]	validation-rmse:8.68848
# [829]	validation-rmse:8.68724
# [830]	validation-rmse:8.68679
# [831]	validation-rmse:8.68621
# [832]	validation-rmse:8.68530
# [833]	validation-rmse:8.68420
# [834]	validation-rmse:8.68310
# [835]	validation-rmse:8.68196
# [836]	validation-rmse:8.68070
# [837]	validation-rmse:8.67947
# [838]	validation-rmse:8.67898
# [839]	validation-rmse:8.67779
# [840]	validation-rmse:8.67611
# [841]	validation-rmse:8.67482
# [842]	validation-rmse:8.67388
# [843]	validation-rmse:8.67296
# [844]	validation-rmse:8.67188
# [845]	validation-rmse:8.67143
# [846]	validation-rmse:8.67044
# [847]	validation-rmse:8.66952
# [848]	validation-rmse:8.66875
# [849]	validation-rmse:8.66771
# [850]	validation-rmse:8.66673
# [851]	validation-rmse:8.66572
# [852]	validation-rmse:8.66499
# [853]	validation-rmse:8.66375
# [854]	validation-rmse:8.66281
# [855]	validation-rmse:8.66223
# [856]	validation-rmse:8.66105
# [857]	validation-rmse:8.66023
# [858]	validation-rmse:8.65880
# [859]	validation-rmse:8.65792
# [860]	validation-rmse:8.65699
# [861]	validation-rmse:8.65595
# [862]	validation-rmse:8.65455
# [863]	validation-rmse:8.65391
# [864]	validation-rmse:8.65262
# [865]	validation-rmse:8.65177
# [866]	validation-rmse:8.65101
# [867]	validation-rmse:8.64995
# [868]	validation-rmse:8.64920
# [869]	validation-rmse:8.64839
# [870]	validation-rmse:8.64800
# [871]	validation-rmse:8.64653
# [872]	validation-rmse:8.64555
# [873]	validation-rmse:8.64416
# [874]	validation-rmse:8.64302
# [875]	validation-rmse:8.64224
# [876]	validation-rmse:8.64198
# [877]	validation-rmse:8.64085
# [878]	validation-rmse:8.63991
# [879]	validation-rmse:8.63902
# [880]	validation-rmse:8.63858
# [881]	validation-rmse:8.63730
# [882]	validation-rmse:8.63626
# [883]	validation-rmse:8.63551
# [884]	validation-rmse:8.63493
# [885]	validation-rmse:8.63428
# [886]	validation-rmse:8.63320
# [887]	validation-rmse:8.63216
# [888]	validation-rmse:8.63101
# [889]	validation-rmse:8.63013
# [890]	validation-rmse:8.62893
# [891]	validation-rmse:8.62789
# [892]	validation-rmse:8.62644
# [893]	validation-rmse:8.62499
# [894]	validation-rmse:8.62415
# [895]	validation-rmse:8.62357
# [896]	validation-rmse:8.62243
# [897]	validation-rmse:8.62145
# [898]	validation-rmse:8.62099
# [899]	validation-rmse:8.61991
# [900]	validation-rmse:8.61925
# [901]	validation-rmse:8.61824
# [902]	validation-rmse:8.61825
# [903]	validation-rmse:8.61769
# [904]	validation-rmse:8.61671
# [905]	validation-rmse:8.61570
# [906]	validation-rmse:8.61437
# [907]	validation-rmse:8.61335
# [908]	validation-rmse:8.61239
# [909]	validation-rmse:8.61213
# [910]	validation-rmse:8.61127
# [911]	validation-rmse:8.61035
# [912]	validation-rmse:8.60932
# [913]	validation-rmse:8.60877
# [914]	validation-rmse:8.60798
# [915]	validation-rmse:8.60648
# [916]	validation-rmse:8.60546
# [917]	validation-rmse:8.60429
# [918]	validation-rmse:8.60346
# [919]	validation-rmse:8.60220
# [920]	validation-rmse:8.60129
# [921]	validation-rmse:8.60053
# [922]	validation-rmse:8.60011
# [923]	validation-rmse:8.59916
# [924]	validation-rmse:8.59804
# [925]	validation-rmse:8.59757
# [926]	validation-rmse:8.59631
# [927]	validation-rmse:8.59522
# [928]	validation-rmse:8.59431
# [929]	validation-rmse:8.59405
# [930]	validation-rmse:8.59291
# [931]	validation-rmse:8.59215
# [932]	validation-rmse:8.59141
# [933]	validation-rmse:8.59069
# [934]	validation-rmse:8.59024
# [935]	validation-rmse:8.58927
# [936]	validation-rmse:8.58808
# [937]	validation-rmse:8.58711
# [938]	validation-rmse:8.58610
# [939]	validation-rmse:8.58499
# [940]	validation-rmse:8.58431
# [941]	validation-rmse:8.58323
# [942]	validation-rmse:8.58210
# [943]	validation-rmse:8.58098
# [944]	validation-rmse:8.58040
# [945]	validation-rmse:8.58009
# [946]	validation-rmse:8.57974
# [947]	validation-rmse:8.57874
# [948]	validation-rmse:8.57762
# [949]	validation-rmse:8.57703
# [950]	validation-rmse:8.57654
# [951]	validation-rmse:8.57572
# [952]	validation-rmse:8.57482
# [953]	validation-rmse:8.57390
# [954]	validation-rmse:8.57336
# [955]	validation-rmse:8.57253
# [956]	validation-rmse:8.57182
# [957]	validation-rmse:8.57180
# [958]	validation-rmse:8.57089
# [959]	validation-rmse:8.57078
# [960]	validation-rmse:8.56963
# [961]	validation-rmse:8.56871
# [962]	validation-rmse:8.56811
# [963]	validation-rmse:8.56706
# [964]	validation-rmse:8.56662
# [965]	validation-rmse:8.56596
# [966]	validation-rmse:8.56496
# [967]	validation-rmse:8.56411
# [968]	validation-rmse:8.56308
# [969]	validation-rmse:8.56292
# [970]	validation-rmse:8.56226
# [971]	validation-rmse:8.56132
# [972]	validation-rmse:8.56045
# [973]	validation-rmse:8.55984
# [974]	validation-rmse:8.55908
# [975]	validation-rmse:8.55788
# [976]	validation-rmse:8.55687
# [977]	validation-rmse:8.55617
# [978]	validation-rmse:8.55503
# [979]	validation-rmse:8.55386
# [980]	validation-rmse:8.55318
# [981]	validation-rmse:8.55225
# [982]	validation-rmse:8.55122
# [983]	validation-rmse:8.55044
# [984]	validation-rmse:8.54978
# [985]	validation-rmse:8.54889
# [986]	validation-rmse:8.54812
# [987]	validation-rmse:8.54737
# [988]	validation-rmse:8.54655
# [989]	validation-rmse:8.54543
# [990]	validation-rmse:8.54444
# [991]	validation-rmse:8.54344
# [992]	validation-rmse:8.54237
# [993]	validation-rmse:8.54219
# [994]	validation-rmse:8.54209
# [995]	validation-rmse:8.54129
# [996]	validation-rmse:8.54105
# [997]	validation-rmse:8.54017
# [998]	validation-rmse:8.53946
# [999]	validation-rmse:8.53955
# 2024/05/30 19:29:16 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.
# 2024/05/30 19:29:16 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/codespace/anaconda3/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [19:29:16] WARNING: /workspace/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# 2024/05/30 19:29:26 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/codespace/anaconda3/lib/python3.9/site-packages/_distutils_hack/__init__.py:30: UserWarning: Setuptools is replacing distutils."
